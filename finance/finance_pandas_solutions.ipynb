# %% [markdown]
# ## 1. Load the dataset and display the first 5 rows.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('finance_dataset_adjusted.csv')
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type   Amount        Date  \
# 0         8878612         1600350         Transfer  3510.07  2023-04-30
# 1         2733712         6056870          Deposit  2522.09  2023-06-22
# 2         5836221         3737324         Transfer  9443.94  2022-09-19
# 3         9755716         1106801          Deposit  9390.66  2023-03-28
# 4         9204424         5001180       Withdrawal  1608.07  2023-07-25
#
#            Merchant  Account_Balance   Category  Fraud_Flag
# 0     Armstrong Inc         91071.08  Utilities       False
# 1  Johnson and Sons         75544.71  Groceries       False
# 2        Lopez-Luna         59332.32     Health       False
# 3         Berry LLC         90189.54     Travel       False
# 4    Smith-Fletcher         38271.10  Groceries        True

# %% [markdown]
# ## 2. Display the summary statistics of the dataset.

# %%
df.describe()
# Out:
#        Transaction_ID  Account_Number       Amount  Account_Balance
# count    1.000000e+03    1.000000e+03  1000.000000      1000.000000
# mean     5.417825e+06    5.609271e+06  5101.042790     50319.013350
# std      2.593520e+06    2.593442e+06  2874.500151     29394.889854
# min      1.005037e+06    1.003263e+06    11.020000       202.910000
# 25%      3.234542e+06    3.419836e+06  2681.020000     24979.345000
# 50%      5.431894e+06    5.670294e+06  5105.460000     50027.815000
# 75%      7.553128e+06    7.866319e+06  7528.772500     75565.512500
# max      9.999940e+06    9.993283e+06  9998.670000     99687.540000

# %% [markdown]
# ## 3. Check for missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Account_Number      0
# Transaction_Type    0
# Amount              0
# Date                0
# Merchant            0
# Account_Balance     0
# Category            0
# Fraud_Flag          0
# dtype: int64

# %% [markdown]
# ## 4. Drop rows with any missing values.

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type   Amount        Date  \
# 0         8878612         1600350         Transfer  3510.07  2023-04-30
# 1         2733712         6056870          Deposit  2522.09  2023-06-22
# 2         5836221         3737324         Transfer  9443.94  2022-09-19
# 3         9755716         1106801          Deposit  9390.66  2023-03-28
# 4         9204424         5001180       Withdrawal  1608.07  2023-07-25
#
#            Merchant  Account_Balance   Category  Fraud_Flag
# 0     Armstrong Inc         91071.08  Utilities       False
# 1  Johnson and Sons         75544.71  Groceries       False
# 2        Lopez-Luna         59332.32     Health       False
# 3         Berry LLC         90189.54     Travel       False
# 4    Smith-Fletcher         38271.10  Groceries        True

# %% [markdown]
# ## 5. Fill missing values with the mean for numerical columns.

# %%
df.fillna(df.mean(), inplace=True)
df.head()
# Out:
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_5774/2956738053.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
#    Transaction_ID  Account_Number Transaction_Type   Amount        Date  \
# 0         8878612         1600350         Transfer  3510.07  2023-04-30
# 1         2733712         6056870          Deposit  2522.09  2023-06-22
# 2         5836221         3737324         Transfer  9443.94  2022-09-19
# 3         9755716         1106801          Deposit  9390.66  2023-03-28
# 4         9204424         5001180       Withdrawal  1608.07  2023-07-25
#
#            Merchant  Account_Balance   Category  Fraud_Flag
# 0     Armstrong Inc         91071.08  Utilities       False
# 1  Johnson and Sons         75544.71  Groceries       False
# 2        Lopez-Luna         59332.32     Health       False
# 3         Berry LLC         90189.54     Travel       False
# 4    Smith-Fletcher         38271.10  Groceries        True

# %% [markdown]
# ## 6. Fill missing values with the mode for categorical columns.

# %%
df.fillna(df.mode().iloc[0], inplace=True)
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type   Amount        Date  \
# 0         8878612         1600350         Transfer  3510.07  2023-04-30
# 1         2733712         6056870          Deposit  2522.09  2023-06-22
# 2         5836221         3737324         Transfer  9443.94  2022-09-19
# 3         9755716         1106801          Deposit  9390.66  2023-03-28
# 4         9204424         5001180       Withdrawal  1608.07  2023-07-25
#
#            Merchant  Account_Balance   Category  Fraud_Flag
# 0     Armstrong Inc         91071.08  Utilities       False
# 1  Johnson and Sons         75544.71  Groceries       False
# 2        Lopez-Luna         59332.32     Health       False
# 3         Berry LLC         90189.54     Travel       False
# 4    Smith-Fletcher         38271.10  Groceries        True

# %% [markdown]
# ## 7. Create a new column 'Transaction_Year' by extracting the year from the 'Date' column.

# %%
df['Date'] = df['Date'].astype('datetime64')
df['Transaction_Year'] = df['Date'].dt.year
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type   Amount       Date  \
# 0         8878612         1600350         Transfer  3510.07 2023-04-30
# 1         2733712         6056870          Deposit  2522.09 2023-06-22
# 2         5836221         3737324         Transfer  9443.94 2022-09-19
# 3         9755716         1106801          Deposit  9390.66 2023-03-28
# 4         9204424         5001180       Withdrawal  1608.07 2023-07-25
#
#            Merchant  Account_Balance   Category  Fraud_Flag  Transaction_Year
# 0     Armstrong Inc         91071.08  Utilities       False              2023
# 1  Johnson and Sons         75544.71  Groceries       False              2023
# 2        Lopez-Luna         59332.32     Health       False              2022
# 3         Berry LLC         90189.54     Travel       False              2023
# 4    Smith-Fletcher         38271.10  Groceries        True              2023

# %% [markdown]
# ## 8. Calculate the correlation matrix for numerical columns.

# %%
df.corr()
# Out:
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_5774/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Transaction_ID  Account_Number    Amount  Account_Balance  \
# Transaction_ID          1.000000       -0.031975  0.032704        -0.028588
# Account_Number         -0.031975        1.000000  0.032287        -0.031221
# Amount                  0.032704        0.032287  1.000000         0.011249
# Account_Balance        -0.028588       -0.031221  0.011249         1.000000
# Fraud_Flag              0.031938       -0.011393 -0.030180        -0.038776
# Transaction_Year        0.023863        0.054791 -0.009038        -0.024338
#
#                   Fraud_Flag  Transaction_Year
# Transaction_ID      0.031938          0.023863
# Account_Number     -0.011393          0.054791
# Amount             -0.030180         -0.009038
# Account_Balance    -0.038776         -0.024338
# Fraud_Flag          1.000000         -0.016731
# Transaction_Year   -0.016731          1.000000

# %% [markdown]
# ## 9. Plot a histogram for the 'Amount' column.

# %%
df['Amount'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ## 10. Plot a bar chart for the 'Transaction_Type' column.

# %%
df['Transaction_Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## 11. Plot a scatter plot between 'Account_Balance' and 'Amount'.

# %%
df.plot.scatter(x='Account_Balance', y='Amount')
# Out:
# <Axes: xlabel='Account_Balance', ylabel='Amount'>

# %% [markdown]
# ## 12. Encode the 'Category' column using one-hot encoding.

# %%
df = pd.get_dummies(df, columns=['Category'])
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type   Amount       Date  \
# 0         8878612         1600350         Transfer  3510.07 2023-04-30
# 1         2733712         6056870          Deposit  2522.09 2023-06-22
# 2         5836221         3737324         Transfer  9443.94 2022-09-19
# 3         9755716         1106801          Deposit  9390.66 2023-03-28
# 4         9204424         5001180       Withdrawal  1608.07 2023-07-25
#
#            Merchant  Account_Balance  Fraud_Flag  Transaction_Year  \
# 0     Armstrong Inc         91071.08       False              2023
# 1  Johnson and Sons         75544.71       False              2023
# 2        Lopez-Luna         59332.32       False              2022
# 3         Berry LLC         90189.54       False              2023
# 4    Smith-Fletcher         38271.10        True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities
# 0                0                   1
# 1                0                   0
# 2                0                   0
# 3                1                   0
# 4                0                   0

# %% [markdown]
# ## 13. Normalize the 'Amount' column using Min-Max scaling.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['Amount'] = scaler.fit_transform(df[['Amount']])
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type    Amount       Date  \
# 0         8878612         1600350         Transfer  0.350338 2023-04-30
# 1         2733712         6056870          Deposit  0.251418 2023-06-22
# 2         5836221         3737324         Transfer  0.944458 2022-09-19
# 3         9755716         1106801          Deposit  0.939124 2023-03-28
# 4         9204424         5001180       Withdrawal  0.159902 2023-07-25
#
#            Merchant  Account_Balance  Fraud_Flag  Transaction_Year  \
# 0     Armstrong Inc         91071.08       False              2023
# 1  Johnson and Sons         75544.71       False              2023
# 2        Lopez-Luna         59332.32       False              2022
# 3         Berry LLC         90189.54       False              2023
# 4    Smith-Fletcher         38271.10        True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities
# 0                0                   1
# 1                0                   0
# 2                0                   0
# 3                1                   0
# 4                0                   0

# %% [markdown]
# ## 14. Standardize the 'Account_Balance' column.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Account_Balance'] = scaler.fit_transform(df[['Account_Balance']])
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type    Amount       Date  \
# 0         8878612         1600350         Transfer  0.350338 2023-04-30
# 1         2733712         6056870          Deposit  0.251418 2023-06-22
# 2         5836221         3737324         Transfer  0.944458 2022-09-19
# 3         9755716         1106801          Deposit  0.939124 2023-03-28
# 4         9204424         5001180       Withdrawal  0.159902 2023-07-25
#
#            Merchant  Account_Balance  Fraud_Flag  Transaction_Year  \
# 0     Armstrong Inc         1.387059       False              2023
# 1  Johnson and Sons         0.858595       False              2023
# 2        Lopez-Luna         0.306782       False              2022
# 3         Berry LLC         1.357055       False              2023
# 4    Smith-Fletcher        -0.410069        True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities
# 0                0                   1
# 1                0                   0
# 2                0                   0
# 3                1                   0
# 4                0                   0

# %% [markdown]
# ## 15. Create a pivot table showing the average 'Amount' for each 'Category'.

# %%
df.pivot_table(values='Amount', index='Category_Groceries', aggfunc='mean')
# Out:
#                       Amount
# Category_Groceries
# 0                   0.509021
# 1                   0.511970

# %% [markdown]
# ## 16. Group the data by 'Fraud_Flag' and calculate the mean 'Amount'.

# %%
df.groupby('Fraud_Flag')['Amount'].mean()
# Out:
# Fraud_Flag
# False    0.518124
# True     0.500757
# Name: Amount, dtype: float64

# %% [markdown]
# ## 17. Filter the dataset for transactions with 'Amount' greater than 5000.

# %%
df_filtered = df[df['Amount'] > 5000]
df_filtered.head()
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, Account_Number, Transaction_Type, Amount, Date, Merchant, Account_Balance, Fraud_Flag, Transaction_Year, Category_Entertainment, Category_Groceries, Category_Health, Category_Travel, Category_Utilities]
# Index: []

# %% [markdown]
# ## 18. Sort the dataset by 'Date' in descending order.

# %%
df.sort_values(by='Date', ascending=False).head()
# Out:
#      Transaction_ID  Account_Number Transaction_Type    Amount       Date  \
# 459         2308158         9201004       Withdrawal  0.149933 2024-01-01
# 595         4140510         9818274          Deposit  0.154348 2023-12-31
# 299         9040130         8752331         Transfer  0.557854 2023-12-30
# 235         8675323         6413337       Withdrawal  0.612713 2023-12-30
# 565         1557711         1334916       Withdrawal  0.843022 2023-12-28
#
#                        Merchant  Account_Balance  Fraud_Flag  \
# 459                Roberts-Berg         1.104252        True
# 595  Marshall, Hammond and Park        -0.325513       False
# 299     Barber, James and Ramos        -0.431512        True
# 235                 Schmitt LLC         0.066651       False
# 565    Parks, Palmer and Flores        -0.306566       False
#
#      Transaction_Year  Category_Entertainment  Category_Groceries  \
# 459              2024                       1                   0
# 595              2023                       0                   0
# 299              2023                       0                   0
# 235              2023                       0                   0
# 565              2023                       0                   0
#
#      Category_Health  Category_Travel  Category_Utilities
# 459                0                0                   0
# 595                1                0                   0
# 299                1                0                   0
# 235                0                1                   0
# 565                0                1                   0

# %% [markdown]
# ## 19. Create a new column 'Net_Balance' by subtracting 'Amount' from 'Account_Balance' for withdrawals.

# %%
df['Net_Balance'] = df['Account_Balance'] - df['Amount']
mask = df['Transaction_Type'] == 'Withdrawal'
df.loc[mask, 'Net_Balance']
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type    Amount       Date  \
# 0         8878612         1600350         Transfer  0.350338 2023-04-30
# 1         2733712         6056870          Deposit  0.251418 2023-06-22
# 2         5836221         3737324         Transfer  0.944458 2022-09-19
# 3         9755716         1106801          Deposit  0.939124 2023-03-28
# 4         9204424         5001180       Withdrawal  0.159902 2023-07-25
#
#            Merchant  Account_Balance  Fraud_Flag  Transaction_Year  \
# 0     Armstrong Inc         1.387059       False              2023
# 1  Johnson and Sons         0.858595       False              2023
# 2        Lopez-Luna         0.306782       False              2022
# 3         Berry LLC         1.357055       False              2023
# 4    Smith-Fletcher        -0.410069        True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972

# %% [markdown]
# ## 20. Replace all instances of 'False' in the 'Fraud_Flag' column with 'No Fraud'.

# %%
df['Fraud_Flag'].replace(False, 'No Fraud', inplace=True)
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type    Amount       Date  \
# 0         8878612         1600350         Transfer  0.350338 2023-04-30
# 1         2733712         6056870          Deposit  0.251418 2023-06-22
# 2         5836221         3737324         Transfer  0.944458 2022-09-19
# 3         9755716         1106801          Deposit  0.939124 2023-03-28
# 4         9204424         5001180       Withdrawal  0.159902 2023-07-25
#
#            Merchant  Account_Balance Fraud_Flag  Transaction_Year  \
# 0     Armstrong Inc         1.387059   No Fraud              2023
# 1  Johnson and Sons         0.858595   No Fraud              2023
# 2        Lopez-Luna         0.306782   No Fraud              2022
# 3         Berry LLC         1.357055   No Fraud              2023
# 4    Smith-Fletcher        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972

# %% [markdown]
# ## 21. Rename the column 'Amount' to 'Transaction_Amount'.

# %%
df.rename(columns={'Amount': 'Transaction_Amount'}, inplace=True)
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date          Merchant  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30     Armstrong Inc         1.387059   No Fraud              2023
# 1 2023-06-22  Johnson and Sons         0.858595   No Fraud              2023
# 2 2022-09-19        Lopez-Luna         0.306782   No Fraud              2022
# 3 2023-03-28         Berry LLC         1.357055   No Fraud              2023
# 4 2023-07-25    Smith-Fletcher        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972

# %% [markdown]
# ## 22. Drop the 'Merchant' column from the dataset.

# %%
df.drop(columns=['Merchant'], inplace=True)
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972

# %% [markdown]
# ## 23. Check for duplicate rows in the dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 24. Drop any duplicate rows found.

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972

# %% [markdown]
# ## 25. Create a new DataFrame containing only 'Transaction_ID', 'Account_Number', and 'Transaction_Amount'.

# %%
df_subset = df[['Transaction_ID', 'Account_Number', 'Transaction_Amount']]
df_subset.head()
# Out:
#    Transaction_ID  Account_Number  Transaction_Amount
# 0         8878612         1600350            0.350338
# 1         2733712         6056870            0.251418
# 2         5836221         3737324            0.944458
# 3         9755716         1106801            0.939124
# 4         9204424         5001180            0.159902

# %% [markdown]
# ## 26. Merge the new DataFrame with the original dataset on 'Transaction_ID'.

# %%
df_merged = pd.merge(df_subset, df, on='Transaction_ID')
df_merged.head()
# Out:
#    Transaction_ID  Account_Number_x  Transaction_Amount_x  Account_Number_y  \
# 0         8878612           1600350              0.350338           1600350
# 1         2733712           6056870              0.251418           6056870
# 2         5836221           3737324              0.944458           3737324
# 3         9755716           1106801              0.939124           1106801
# 4         9204424           5001180              0.159902           5001180
#
#   Transaction_Type  Transaction_Amount_y       Date  Account_Balance  \
# 0         Transfer              0.350338 2023-04-30         1.387059
# 1          Deposit              0.251418 2023-06-22         0.858595
# 2         Transfer              0.944458 2022-09-19         0.306782
# 3          Deposit              0.939124 2023-03-28         1.357055
# 4       Withdrawal              0.159902 2023-07-25        -0.410069
#
#   Fraud_Flag  Transaction_Year  Category_Entertainment  Category_Groceries  \
# 0   No Fraud              2023                       0                   0
# 1   No Fraud              2023                       0                   1
# 2   No Fraud              2022                       0                   0
# 3   No Fraud              2023                       0                   0
# 4       True              2023                       0                   1
#
#    Category_Health  Category_Travel  Category_Utilities  Net_Balance
# 0                0                0                   1     1.036722
# 1                0                0                   0     0.607178
# 2                1                0                   0    -0.637677
# 3                0                1                   0     0.417931
# 4                0                0                   0    -0.569972

# %% [markdown]
# ## 27. Create a cross-tabulation of 'Category' and 'Fraud_Flag'.

# %%
pd.crosstab(df['Category_Entertainment'], df['Fraud_Flag'])
# Out:
# Fraud_Flag              True  No Fraud
# Category_Entertainment
# 0                        386       425
# 1                        103        86

# %% [markdown]
# ## 28. Create a pivot table showing the count of transactions by 'Category' and 'Transaction_Type'.

# %%
df.pivot_table(index='Category_Groceries', columns='Transaction_Type', aggfunc='size', fill_value=0)
# Out:
# Transaction_Type    Deposit  Payment  Transfer  Withdrawal
# Category_Groceries
# 0                       200      198       192         203
# 1                        52       54        50          51

# %% [markdown]
# ## 29. Replace missing values in 'Account_Balance' with the median.

# %%
df['Account_Balance'].fillna(df['Account_Balance'].median(), inplace=True)
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972

# %% [markdown]
# ## 30. Calculate the Z-score for the 'Transaction_Amount' column.

# %%
from scipy.stats import zscore
df['Transaction_Amount_Zscore'] = zscore(df['Transaction_Amount'])
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  Transaction_Amount_Zscore
# 0                0                   1     1.036722                  -0.553755
# 1                0                   0     0.607178                  -0.897632
# 2                0                   0    -0.637677                   1.511592
# 3                1                   0     0.417931                   1.493047
# 4                0                   0    -0.569972                  -1.215766

# %% [markdown]
# ## 31. Filter out outliers in the 'Transaction_Amount' column based on Z-score.

# %%
df_no_outliers = df[(df['Transaction_Amount_Zscore'] > -3) & (df['Transaction_Amount_Zscore'] < 3)]
df_no_outliers.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  Transaction_Amount_Zscore
# 0                0                   1     1.036722                  -0.553755
# 1                0                   0     0.607178                  -0.897632
# 2                0                   0    -0.637677                   1.511592
# 3                1                   0     0.417931                   1.493047
# 4                0                   0    -0.569972                  -1.215766

# %% [markdown]
# ## 32. Apply a lambda function to the 'Transaction_Amount' column to categorize into 'Low', 'Medium', 'High'.

# %%
df['Transaction_Amount_Category'] = df['Transaction_Amount'].apply(lambda x: 'Low' if x < 2000 else 'Medium' if x < 6000 else 'High')
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category
# 0                  -0.553755                         Low
# 1                  -0.897632                         Low
# 2                   1.511592                         Low
# 3                   1.493047                         Low
# 4                  -1.215766                         Low

# %% [markdown]
# ## 33. Create a new column 'Total_Expenditure' by summing up all 'Transaction_Amount' for withdrawals.

# %%
df['Total_Expenditure'] = df.groupby('Account_Number')['Transaction_Amount'].transform('sum')
mask = df['Transaction_Type'] == 'Withdrawal'
df.loc[mask, 'Total_Expenditure']
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902

# %% [markdown]
# ## 34. Extract the month from 'Date' and create a new column 'Transaction_Month'.

# %%
df['Transaction_Month'] = df['Date'].dt.month
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902
#
#    Transaction_Month
# 0                  4
# 1                  6
# 2                  9
# 3                  3
# 4                  7

# %% [markdown]
# ## 35. Convert the 'Transaction_Type' column to a categorical data type.

# %%
df['Transaction_Type'] = df['Transaction_Type'].astype('category')
df.dtypes
# Out:
# Transaction_ID                          int64
# Account_Number                          int64
# Transaction_Type                     category
# Transaction_Amount                    float64
# Date                           datetime64[ns]
# Account_Balance                       float64
# Fraud_Flag                             object
# Transaction_Year                        int64
# Category_Entertainment                  uint8
# Category_Groceries                      uint8
# Category_Health                         uint8
# Category_Travel                         uint8
# Category_Utilities                      uint8
# Net_Balance                           float64
# Transaction_Amount_Zscore             float64
# Transaction_Amount_Category            object
# Total_Expenditure                     float64
# Transaction_Month                       int64
# dtype: object

# %% [markdown]
# ## 36. Create a box plot for 'Transaction_Amount' across different 'Category'.

# %%
df.boxplot(column='Transaction_Amount', by='Category_Groceries')
# Out:
# <Axes: title={'center': 'Transaction_Amount'}, xlabel='Category_Groceries'>

# %% [markdown]
# ## 37. Create a line plot showing the trend of 'Transaction_Amount' over 'Date'.

# %%
df.groupby('Date')['Transaction_Amount'].mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 38. Create a heatmap for the correlation matrix.

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_5774/3898237727.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %% [markdown]
# ## 39. Filter the dataset to include only transactions with 'Fraud_Flag' as 'True'.

# %%
df_fraud = df[df['Fraud_Flag'] == True]
df_fraud.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 4         9204424         5001180       Withdrawal            0.159902
# 6         8522573         2113624         Transfer            0.480007
# 7         7209487         7921401       Withdrawal            0.890916
# 8         8504784         3154078       Withdrawal            0.267594
# 9         8312246         3559999         Transfer            0.610958
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 4 2023-07-25        -0.410069       True              2023
# 6 2023-02-10         0.589601       True              2023
# 7 2022-06-25         0.708883       True              2022
# 8 2023-03-14         0.889754       True              2023
# 9 2023-01-05         1.138126       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 4                       0                   1                0
# 6                       0                   1                0
# 7                       0                   1                0
# 8                       0                   0                0
# 9                       0                   0                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 4                0                   0    -0.569972
# 6                0                   0     0.109594
# 7                0                   0    -0.182033
# 8                0                   1     0.622159
# 9                1                   0     0.527168
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 4                  -1.215766                         Low           0.159902
# 6                  -0.102985                         Low           0.480007
# 7                   1.325463                         Low           0.890916
# 8                  -0.841396                         Low           0.267594
# 9                   0.352240                         Low           0.610958
#
#    Transaction_Month
# 4                  7
# 6                  2
# 7                  6
# 8                  3
# 9                  1

# %% [markdown]
# ## 40. Replace outliers in 'Account_Balance' with the median value.

# %%
median_value = df['Account_Balance'].median()
df.loc[df['Account_Balance'] > df['Account_Balance'].quantile(0.99), 'Account_Balance'] = median_value
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902
#
#    Transaction_Month
# 0                  4
# 1                  6
# 2                  9
# 3                  3
# 4                  7

# %% [markdown]
# ## 41. Calculate the percentage of missing values in each column.

# %%
missing_percent = df.isnull().mean() * 100
missing_percent
# Out:
# Transaction_ID                 0.0
# Account_Number                 0.0
# Transaction_Type               0.0
# Transaction_Amount             0.0
# Date                           0.0
# Account_Balance                0.0
# Fraud_Flag                     0.0
# Transaction_Year               0.0
# Category_Entertainment         0.0
# Category_Groceries             0.0
# Category_Health                0.0
# Category_Travel                0.0
# Category_Utilities             0.0
# Net_Balance                    0.0
# Transaction_Amount_Zscore      0.0
# Transaction_Amount_Category    0.0
# Total_Expenditure              0.0
# Transaction_Month              0.0
# dtype: float64

# %% [markdown]
# ## 42. Reorder the columns so that 'Transaction_ID' is the first column.

# %%
df = df[['Transaction_ID'] + [col for col in df.columns if col != 'Transaction_ID']]
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902
#
#    Transaction_Month
# 0                  4
# 1                  6
# 2                  9
# 3                  3
# 4                  7

# %% [markdown]
# ## 43. Create a column 'High_Value_Transaction' which is True if 'Transaction_Amount' > 8000, else False.

# %%
df['High_Value_Transaction'] = df['Transaction_Amount'] > 8000
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer            0.350338
# 1         2733712         6056870          Deposit            0.251418
# 2         5836221         3737324         Transfer            0.944458
# 3         9755716         1106801          Deposit            0.939124
# 4         9204424         5001180       Withdrawal            0.159902
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.387059   No Fraud              2023
# 1 2023-06-22         0.858595   No Fraud              2023
# 2 2022-09-19         0.306782   No Fraud              2022
# 3 2023-03-28         1.357055   No Fraud              2023
# 4 2023-07-25        -0.410069       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902
#
#    Transaction_Month  High_Value_Transaction
# 0                  4                   False
# 1                  6                   False
# 2                  9                   False
# 3                  3                   False
# 4                  7                   False

# %% [markdown]
# ## 44. Split the dataset into training (80%) and testing (20%) sets based on 'Transaction_ID'.

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.2, random_state=42)
train.shape, test.shape
# Out:
# ((800, 19), (200, 19))

# %% [markdown]
# ## 45. Create a pipeline to preprocess the 'Transaction_Amount' and 'Account_Balance' columns.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipeline = Pipeline([
    ('scaler', StandardScaler())
])
df[['Transaction_Amount', 'Account_Balance']] = pipeline.fit_transform(df[['Transaction_Amount', 'Account_Balance']])
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer           -0.553755
# 1         2733712         6056870          Deposit           -0.897632
# 2         5836221         3737324         Transfer            1.511592
# 3         9755716         1106801          Deposit            1.493047
# 4         9204424         5001180       Withdrawal           -1.215766
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.424040   No Fraud              2023
# 1 2023-06-22         0.887977   No Fraud              2023
# 2 2022-09-19         0.328228   No Fraud              2022
# 3 2023-03-28         1.393604   No Fraud              2023
# 4 2023-07-25        -0.398931       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902
#
#    Transaction_Month  High_Value_Transaction
# 0                  4                   False
# 1                  6                   False
# 2                  9                   False
# 3                  3                   False
# 4                  7                   False

# %% [markdown]
# ## 46. Export the cleaned dataset to a new CSV file.

# %%
df.to_csv('cleaned_finance_dataset.csv', index=False)

# %% [markdown]
# ## 47. Save the dataset in Excel format with multiple sheets based on 'Category'.

# %%
with pd.ExcelWriter('finance_by_category.xlsx') as writer:
    for category in ['Category_Groceries', 'Category_Utilities', 'Category_Entertainment', 'Category_Travel', 'Category_Health']:
        df[df[category] == 1].to_excel(writer, sheet_name=category, index=False)

# %% [markdown]
# ## 48. Create a summary report of the dataset including key statistics and visualizations.

# %%
df.describe(include='all')
# Out:
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_5774/2884002236.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#         Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# count     1.000000e+03    1.000000e+03             1000        1.000000e+03
# unique             NaN             NaN                4                 NaN
# top                NaN             NaN       Withdrawal                 NaN
# freq               NaN             NaN              254                 NaN
# first              NaN             NaN              NaN                 NaN
# last               NaN             NaN              NaN                 NaN
# mean      5.417825e+06    5.609271e+06              NaN        1.256772e-16
# std       2.593520e+06    2.593442e+06              NaN        1.000500e+00
# min       1.005037e+06    1.003263e+06              NaN       -1.771637e+00
# 25%       3.234542e+06    3.419836e+06              NaN       -8.423147e-01
# 50%       5.431894e+06    5.670294e+06              NaN        1.537457e-03
# 75%       7.553128e+06    7.866319e+06              NaN        8.449972e-01
# max       9.999940e+06    9.993283e+06              NaN        1.704671e+00
#
#                        Date  Account_Balance Fraud_Flag  Transaction_Year  \
# count                  1000     1.000000e+03       1000       1000.000000
# unique                  553              NaN          2               NaN
# top     2023-12-01 00:00:00              NaN   No Fraud               NaN
# freq                      6              NaN        511               NaN
# first   2022-01-02 00:00:00              NaN        NaN               NaN
# last    2024-01-01 00:00:00              NaN        NaN               NaN
# mean                    NaN    -2.353673e-17        NaN       2022.528000
# std                     NaN     1.000500e+00        NaN          0.501465
# min                     NaN    -1.713273e+00        NaN       2022.000000
# 25%                     NaN    -8.578422e-01        NaN       2022.000000
# 50%                     NaN     5.701144e-03        NaN       2023.000000
# 75%                     NaN     8.559593e-01        NaN       2023.000000
# max                     NaN     1.687622e+00        NaN       2024.000000
#
#         Category_Entertainment  Category_Groceries  Category_Health  \
# count              1000.000000         1000.000000      1000.000000
# unique                     NaN                 NaN              NaN
# top                        NaN                 NaN              NaN
# freq                       NaN                 NaN              NaN
# first                      NaN                 NaN              NaN
# last                       NaN                 NaN              NaN
# mean                  0.189000            0.207000         0.213000
# std                   0.391705            0.405358         0.409633
# min                   0.000000            0.000000         0.000000
# 25%                   0.000000            0.000000         0.000000
# 50%                   0.000000            0.000000         0.000000
# 75%                   0.000000            0.000000         0.000000
# max                   1.000000            1.000000         1.000000
#
#         Category_Travel  Category_Utilities  Net_Balance  \
# count       1000.000000          1000.00000  1000.000000
# unique              NaN                 NaN          NaN
# top                 NaN                 NaN          NaN
# freq                NaN                 NaN          NaN
# first               NaN                 NaN          NaN
# last                NaN                 NaN          NaN
# mean           0.199000             0.19200    -0.509632
# std            0.399448             0.39407     1.037957
# min            0.000000             0.00000    -2.582975
# 25%            0.000000             0.00000    -1.357333
# 50%            0.000000             0.00000    -0.517396
# 75%            0.000000             0.00000     0.368453
# max            1.000000             1.00000     1.636605
#
#         Transaction_Amount_Zscore Transaction_Amount_Category  \
# count                1.000000e+03                        1000
# unique                        NaN                           1
# top                           NaN                         Low
# freq                          NaN                        1000
# first                         NaN                         NaN
# last                          NaN                         NaN
# mean                 1.256772e-16                         NaN
# std                  1.000500e+00                         NaN
# min                 -1.771637e+00                         NaN
# 25%                 -8.423147e-01                         NaN
# 50%                  1.537457e-03                         NaN
# 75%                  8.449972e-01                         NaN
# max                  1.704671e+00                         NaN
#
#         Total_Expenditure  Transaction_Month High_Value_Transaction
# count         1000.000000        1000.000000                   1000
# unique                NaN                NaN                      1
# top                   NaN                NaN                  False
# freq                  NaN                NaN                   1000
# first                 NaN                NaN                    NaN
# last                  NaN                NaN                    NaN
# mean             0.509632           6.653000                    NaN
# std              0.287805           3.530305                    NaN
# min              0.000000           1.000000                    NaN
# 25%              0.267330           3.000000                    NaN
# 50%              0.510074           7.000000                    NaN
# 75%              0.752705          10.000000                    NaN
# max              1.000000          12.000000                    NaN

# %% [markdown]
# ## 49. Write a function to automate the data cleaning process for this dataset.

# %%
def clean_data(df):
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)
    df.fillna(df.mean(), inplace=True)
    return df

cleaned_df = clean_data(df.copy())
cleaned_df.head()
# Out:
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_5774/4228417632.py:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(), inplace=True)
# /var/folders/v2/fmm4xb9j1vvd6n08b20728rw0000gn/T/ipykernel_5774/4228417632.py:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer           -0.553755
# 1         2733712         6056870          Deposit           -0.897632
# 2         5836221         3737324         Transfer            1.511592
# 3         9755716         1106801          Deposit            1.493047
# 4         9204424         5001180       Withdrawal           -1.215766
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.424040   No Fraud              2023
# 1 2023-06-22         0.887977   No Fraud              2023
# 2 2022-09-19         0.328228   No Fraud              2022
# 3 2023-03-28         1.393604   No Fraud              2023
# 4 2023-07-25        -0.398931       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902
#
#    Transaction_Month  High_Value_Transaction
# 0                  4                   False
# 1                  6                   False
# 2                  9                   False
# 3                  3                   False
# 4                  7                   False

# %% [markdown]
# ## 50. Create a new column 'Transaction_Risk_Score' using a simple formula on 'Amount' and 'Fraud_Flag'.

# %%
df['Transaction_Risk_Score'] = df['Transaction_Amount'].astype(int) * df['Fraud_Flag']
df.head()
# Out:
#    Transaction_ID  Account_Number Transaction_Type  Transaction_Amount  \
# 0         8878612         1600350         Transfer           -0.553755
# 1         2733712         6056870          Deposit           -0.897632
# 2         5836221         3737324         Transfer            1.511592
# 3         9755716         1106801          Deposit            1.493047
# 4         9204424         5001180       Withdrawal           -1.215766
#
#         Date  Account_Balance Fraud_Flag  Transaction_Year  \
# 0 2023-04-30         1.424040   No Fraud              2023
# 1 2023-06-22         0.887977   No Fraud              2023
# 2 2022-09-19         0.328228   No Fraud              2022
# 3 2023-03-28         1.393604   No Fraud              2023
# 4 2023-07-25        -0.398931       True              2023
#
#    Category_Entertainment  Category_Groceries  Category_Health  \
# 0                       0                   0                0
# 1                       0                   1                0
# 2                       0                   0                1
# 3                       0                   0                0
# 4                       0                   1                0
#
#    Category_Travel  Category_Utilities  Net_Balance  \
# 0                0                   1     1.036722
# 1                0                   0     0.607178
# 2                0                   0    -0.637677
# 3                1                   0     0.417931
# 4                0                   0    -0.569972
#
#    Transaction_Amount_Zscore Transaction_Amount_Category  Total_Expenditure  \
# 0                  -0.553755                         Low           0.350338
# 1                  -0.897632                         Low           0.251418
# 2                   1.511592                         Low           0.944458
# 3                   1.493047                         Low           0.939124
# 4                  -1.215766                         Low           0.159902
#
#    Transaction_Month  High_Value_Transaction Transaction_Risk_Score
# 0                  4                   False
# 1                  6                   False
# 2                  9                   False               No Fraud
# 3                  3                   False               No Fraud
# 4                  7                   False                     -1
